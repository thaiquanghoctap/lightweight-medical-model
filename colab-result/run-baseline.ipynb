# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PATH = "/content/drive/MyDrive/Master/LTAINC"

# %% [markdown]
# # MK-Unet

# %%
# %cd $PATH/MK-UNet
# Out:
# /content/drive/.shortcut-targets-by-id/1ZFqnT5X12mwOahLquEp8JkauidLAaHGb/LTAINC/MK-UNet

# %%
# !ls
# Out:
# data			 outputs_cu	requirements_busi.txt  train_polyp.py
# LICENSE			 preprocess.py	requirements.txt       utils
# mkunet_architecture.png  __pycache__	test_polyp.py
# mkunet_network.py	 README.md	train_busi.py

# %%
# !python preprocess.py --dataset busi
# Out:
# train: images=(545, 224, 224, 3), masks=(545, 224, 224), labels=(545, 1)
#   Saved 0/545 BUSI images
#   Saved 100/545 BUSI images
#   Saved 200/545 BUSI images
#   Saved 300/545 BUSI images
#   Saved 400/545 BUSI images
#   Saved 500/545 BUSI images
# val: images=(115, 224, 224, 3), masks=(115, 224, 224), labels=(115, 1)
#   Saved 0/115 BUSI images
#   Saved 100/115 BUSI images
# test: images=(120, 224, 224, 3), masks=(120, 224, 224), labels=(120, 1)
#   Saved 0/120 BUSI images
#   Saved 100/120 BUSI images
# Processed dataset saved to: data/busi

# %%
# !python train_busi.py \
--image-size 224 \
--epochs 100 \
--batch-size 16 \
--learning-rate 5e-4 \
--weight-decay 1e-4 \
--runs 1 \
--patience 20 \
--include-normal
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.12/dist-packages/timm/models/helpers.py:7: FutureWarning: Importing from timm.models.helpers is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# ...

# %% [markdown]
# # CMUNeXt

# %%
# %cd $PATH/CMUNeXt
# Out:
# /content/drive/.shortcut-targets-by-id/1ZFqnT5X12mwOahLquEp8JkauidLAaHGb/LTAINC/CMUNeXt

# %%
# !ls
# Out:
# data	    LICENSE  outputs_cu     requirements_busi.txt  train_busi.py
# dataloader  main.py  preprocess.py  requirements.txt	   utils
# imgs	    network  README.md	    split.py

# %%
# !python preprocess.py --dataset busi
# Out:
# train: images=(545, 224, 224, 3), masks=(545, 224, 224), labels=(545, 1)
#   Saved 0/545 BUSI images
#   Saved 100/545 BUSI images
#   Saved 200/545 BUSI images
#   Saved 300/545 BUSI images
#   Saved 400/545 BUSI images
#   Saved 500/545 BUSI images
# val: images=(115, 224, 224, 3), masks=(115, 224, 224), labels=(115, 1)
#   Saved 0/115 BUSI images
#   Saved 100/115 BUSI images
# test: images=(120, 224, 224, 3), masks=(120, 224, 224), labels=(120, 1)
#   Saved 0/120 BUSI images
#   Saved 100/120 BUSI images
# Processed dataset saved to: data/busi

# %%
# !python train_busi.py \
--image-size 224 \
--epochs 100 \
--batch-size 16 \
--learning-rate 0.01 \
--weight-decay 1e-4 \
--patience 100 \
--include-normal
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# Model: CMUNeXt | Device: cuda | Parameters: 3,149,185
# train: 545 image-mask pairs
# val: 115 image-mask pairs
# test: 120 image-mask pairs
# ...

# %% [markdown]
# # MA-DTNET

# %%
# %cd $PATH/MA-DTNET
# Out:
# /content/drive/MyDrive/Master/LTAINC/MA-DTNET

# %%
# !ls
# Out:
# CSMAM.py       model_loader.py	    preprocess.py	   train_busi.py
# data	       models_multitask.py  __pycache__		   train.py
# dataloader.py  morpholayers.py	    README.md		   utils_metrics.py
# evaluate.py    outputs		    requirements_busi.txt  utils.py

# %%
# !python preprocess.py --dataset busi
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Master/LTAINC/MA-DTNET/preprocess.py", line 163, in <module>
#     preprocess(args.dataset, args.data_dir, args.overwrite)
#   File "/content/drive/MyDrive/Master/LTAINC/MA-DTNET/preprocess.py", line 146, in preprocess
#     preprocess_busi(data_dir, overwrite)
#   File "/content/drive/MyDrive/Master/LTAINC/MA-DTNET/preprocess.py", line 124, in preprocess_busi
#     prepare_output_dir(output_dir, overwrite)
#   File "/content/drive/MyDrive/Master/LTAINC/MA-DTNET/preprocess.py", line 50, in prepare_output_dir
#     raise FileExistsError(
# FileExistsError: Output already exists: data/busi. Use --overwrite to replace it.

# %%
# !pip install segmentation_models_pytorch -q
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 16.2 MB/s eta 0:00:00
# ...

# %%
# !python train_busi.py \
--image-size 224 \
--epochs 100 \
--batch-size 16 \
--learning-rate 1e-4 \
--weight-decay 0.0 \
--patience 20 \
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# Model: MA-DTNet (3-class adapter) | Device: cuda | Parameters: 22,946,524
# train: 545 image-label-mask samples
# val: 115 image-label-mask samples
# test: 120 image-label-mask samples
# ...
