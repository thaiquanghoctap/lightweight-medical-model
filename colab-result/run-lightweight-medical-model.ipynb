# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PATH = "/content/drive/MyDrive/Master/LTAINC"

# %%
# %cd $PATH
# !git clone https://github.com/thaiquanghoctap/lightweight-medical-model.git
# Out:
# /content/drive/MyDrive/Master/HMUD PPNCKH
# Cloning into 'lightweight-medical-model'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 7 (delta 0), reused 7 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), 6.70 KiB | 857.00 KiB/s, done.

# %%
# %cd $PATH/lightweight-medical-model
# Out:
# /content/drive/.shortcut-targets-by-id/1ZFqnT5X12mwOahLquEp8JkauidLAaHGb/LTAINC/lightweight-medical-model

# %%
# !ls outputs/busi
# Out:
# classification_cu  mk_mnet  multi  r_cbam_mnet	segmentation

# %%
# !git status
# Out:
# Refresh index: 100% (17/17), done.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 7 (delta 6), reused 7 (delta 6), pack-reused 0 (from 0)
# Unpacking objects: 100% (7/7), 1.45 KiB | 1024 bytes/s, done.
# From https://github.com/thaiquanghoctap/lightweight-medical-model
#  * branch            main       -> FETCH_HEAD
#    5dc7917..9940590  main       -> origin/main
# Updating 5dc7917..9940590
# Fast-forward
#  test_mk_mnet.py              |  6 +--
#  test_r_cbam_mnet.py          |  6 +--
#  train_busi_classification.py |  3 +-
#  train_mk_mnet.py             | 87 ++++++++++++++++++++------------------------
#  train_r_cbam_mnet.py         | 86 +++++++++++++++++++------------------------
#  5 files changed, 85 insertions(+), 103 deletions(-)

# %% [markdown]
# # BUSI

# %% [markdown]
# ## Classification with MedNet origin

# %%
# classification
# !python train_busi_classification.py \
--epochs 100 \
--batch-size 16 \
--learning-rate 3e-4 \
--weight-decay 1e-4 \
--patience 100
# Out:
# Dataset: busi
# Device: cuda
# Image sizes: [224]
# CBAM modes: [True]
# Runs per configuration: 1
# Total training sessions: 1
#
# ===== Image size: 224 | CBAM: True | Run: 1/1 =====
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# train: 545 classification images
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# val: 115 classification images
# ...

# %%
# !python test_busi_classification.py
# Out:
# Saved 9 classification images to outputs/busi/classification/img_224/test_images

# %% [markdown]
# ## Segmentation and Multitask with basic segment decoder

# %%
# !python train_busi_segmentation.py
# Out:
# Dataset: busi segmentation
# Device: cuda
# Image size: 224
# CBAM: True
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# train: 545 image-mask pairs
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# val: 115 image-mask pairs
# test: 120 image-mask pairs
# ...

# %%
# !python test_busi_segmentation.py
# Out:
# Saved 9 segmentation panels to outputs/busi/segmentation/img_224/test_images

# %%
# !python train_busi_multi.py
# Out:
# Dataset: busi multi-task
# Device: cuda
# Image size: 224
# CBAM: True
# Segmentation weight: 1.0
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# train: 545 image-label-mask samples
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# val: 115 image-label-mask samples
# test: 120 image-label-mask samples
# ...

# %%
# !python test_busi_multi.py
# Out:
# Saved 9 multi-task panels to outputs/busi/multi/img_224/test_images

# %% [markdown]
# ## R-CBAM MT

# %%
# !python train_r_cbam_mnet.py \
--image-size 224 \
--segmentation-weight 1.2 \
--epochs 100 \
--batch-size 16 \
--learning-rate 1e-3 \
--weight-decay 1e-3 \
--patience 100
# Out:
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# train: 545 image-label-mask samples
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# val: 115 image-label-mask samples
# test: 120 image-label-mask samples
# Model: R-CBAM MNet
# Device: cuda
# Image size: 224
# Parameters: 6,559,314
# Segmentation weight: 1.2
# ...

# %%
# !python test_r_cbam_mnet.py \
  --image-size 224 \
  --segmentation-weight 1.0 \
  --learning-rate 1e-3 \
  --weight-decay 1e-3 \
  --patience 100
# Out:
# /content/drive/.shortcut-targets-by-id/1ZFqnT5X12mwOahLquEp8JkauidLAaHGb/LTAINC/lightweight-medical-model/test_r_cbam_mnet.py:71: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   return Image.fromarray(mask.astype(np.uint8) * 255, mode="L").convert("RGB")
# Checkpoint: outputs/busi/r_cbam_mnet/img_224/seg_weight_1/lr_0.001/weight_decay_0.001/patience_20/best_joint.pt
# Saved 9 prediction panels to: outputs/busi/r_cbam_mnet/img_224/seg_weight_1/lr_0.001/weight_decay_0.001/patience_20/test_images

# %% [markdown]
# ## MKUNET

# %%
# !python train_mk_mnet.py --width-mult 0.5 \
--image-size 224 \
--lambda 0.8 \
--epochs 100 \
--batch-size 16 \
--learning-rate 3e-3 \
--weight-decay 1e-3 \
--patience 100
# Out:
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# train: 545 image-label-mask samples
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# val: 115 image-label-mask samples
# test: 120 image-label-mask samples
# Model: MK-MNet
# Device: cuda
# Image size: 224
# Width multiplier: 0.5
# Parameters: 2,250,867
# Deep supervision: True
# Lambda (segmentation weight): 0.8
# ...

# %%
# !python test_r_cbam_mnet.py --width-mult 0.25 \
--image-size 224 \
--lambda 0.8 \
--epochs 100 \
--batch-size 16 \
--learning-rate 1e-3 \
--weight-decay 1e-3 \
--patience 100 \
--num-samples 20

# %% [markdown]
# # Blood MNIST

# %%
# !python preprocess.py --dataset bloodmnist
# Out:
# train: images=(11959, 224, 224, 3), labels=(11959, 1)
#   Saved 0/11959 images
#   Saved 1000/11959 images
#   Saved 2000/11959 images
#   Saved 3000/11959 images
#   Saved 4000/11959 images
#   Saved 5000/11959 images
#   Saved 6000/11959 images
#   Saved 7000/11959 images
#   Saved 8000/11959 images
#   Saved 9000/11959 images
#   Saved 10000/11959 images
#   Saved 11000/11959 images
# val: images=(1712, 224, 224, 3), labels=(1712, 1)
#   Saved 0/1712 images
#   Saved 1000/1712 images
# test: images=(3421, 224, 224, 3), labels=(3421, 1)
#   Saved 0/3421 images
#   Saved 1000/3421 images
#   Saved 2000/3421 images
#   Saved 3000/3421 images
# Processed dataset saved to: data/bloodmnist

# %%
# !python train.py --dataset bloodmnist
# Out:
# Dataset: bloodmnist
# Device: cuda
# Image sizes: [224]
# CBAM modes: [True]
# Runs per configuration: 1
# Total training sessions: 1
#
# ===== Image size: 224 | CBAM: True | Run: 1/1 =====
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# ...

# %% [markdown]
# # Derma MNIST

# %%
# !python preprocess.py --dataset dermamnist
# Out:
# train: images=(7007, 224, 224, 3), labels=(7007, 1)
#   Saved 0/7007 images
#   Saved 1000/7007 images
#   Saved 2000/7007 images
#   Saved 3000/7007 images
#   Saved 4000/7007 images
#   Saved 5000/7007 images
#   Saved 6000/7007 images
#   Saved 7000/7007 images
# val: images=(1003, 224, 224, 3), labels=(1003, 1)
#   Saved 0/1003 images
#   Saved 1000/1003 images
# test: images=(2005, 224, 224, 3), labels=(2005, 1)
#   Saved 0/2005 images
#   Saved 1000/2005 images
#   Saved 2000/2005 images
# Processed dataset saved to: data/dermamnist

# %%
# !python train.py --dataset dermamnist
# Out:
# Dataset: dermamnist
# Device: cuda
# Image sizes: [224]
# CBAM modes: [True]
# Runs per configuration: 1
# Total training sessions: 1
#
# ===== Image size: 224 | CBAM: True | Run: 1/1 =====
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# ...
